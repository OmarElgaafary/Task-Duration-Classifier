# %% [markdown]
# # Data Analysis for the 'Task-Time-Predictor' model
#
# __Firstly, we import the .csv file.__

# %%
import pandas as pd
df = pd.read_csv('../GFG_FINAL.csv')
print(len(df))
# Out:
# 49000
